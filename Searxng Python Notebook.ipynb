# %%
import requests

# %%
def websearch(query,engine='google',pageno=1):
    try:
        searxng_url = 'http://127.0.0.1:8080/search'
 
        params = {
            'q': query,
            'format': 'json',
            'pageno':pageno,
            'engines':engine
        }
        
        response = requests.get(searxng_url, params=params)
        response.raise_for_status()
        results = response.json()
        return results

    except Exception as e:
        print(f'Exception in websearch = {str(e)}')
        return None

# %%
ans = websearch('sambavi venkatesan npi')

# %%
ans
# Out:
# {'query': 'sambavi venkatesan npi',
#  'number_of_results': 0,
#  'results': [{'url': 'https://npiregistry.cms.hhs.gov/provider-view/1902560725',
#    'title': 'Provider Information for 1902560725',
#    'content': 'SAMBAVI VENKATESAN. Gender: Female. NPI: 1902560725. Last Updated: 2021-10-27. Certification Date: 2021-10-27. Details. Name, Value. NPI, 1902560725.',
#    'thumbnail': None,
#    'engine': 'google',
#    'template': 'default.html',
#    'parsed_url': ['https',
#     'npiregistry.cms.hhs.gov',
#     '/provider-view/1902560725',
#     '',
#     '',
#     ''],
#    'engines': ['google'],
#    'positions': [1],
#    'score': 1.0,
#    'category': 'general'},
#   {'url': 'https://www.hipaaspace.com/medical_billing/coding/national_provider_identifier/codes/npi_1902560725.aspx',
#    'title': '1902560725 NPI Number | SAMBAVI VENKATESAN | ...',
#    'content': 'NPI Number, 1902560725 ; Provider Name, SAMBAVI VENKATESAN ; Entity Type, Individual ; Most Important Dates ; Provider Enumeration Date, 10/27/2021.',
#    'thumbnail': None,
#    'engine': 'google',
#    'template': 'default.html',
#    'parsed_url': ['https',
#     'www.hipaaspace.com',
#     '/medical_billing/coding/national_provider_identifier/codes/npi_1902560725.aspx',
#     '',
#     '',
#     ''],
#    'engines': ['google'],
#    'positions': [2],
#    'score': 0.5,
#    'category': 'general'},
#   {'url': 'https://npidb.org/doctors/behavioral_health/professional_101yp2500x/1902560725.aspx',
#    'title': 'SAMBAVI VENKATESAN, Professional AUSTIN, TX',
#    'content': '27-Oct-2021 — NPI Profile & details for SAMBAVI VENKATESAN · (Female). NPI #, 1902560725. Status, Active. Credentials.',
#    'thumbnail': None,
#    'engine': 'google',
#    'template': 'default.html',
#    'parsed_url': ['https',
#     'npidb.org',
#     '/doctors/behavioral_health/professional_101yp2500x/1902560725.aspx',
#     '',
#     '',
#     ''],
#    'engines': ['google'],
#    'positions': [3],
#    'score': 0.3333333333333333,
#    'category': 'general'},
#   {'url': 'https://npiprofile.com/npi/1902560725',
#    'title': 'SAMBAVI VENKATESAN - Counselor in Austin, TX',
#    'content': "The healthcare provider is registered in the NPI registry with number 1902560725 assigned on October 2021. The practitioner's primary taxonomy code is ...",
#    'thumbnail': None,
#    'engine': 'google',
#    'template': 'default.html',
#    'parsed_url': ['https', 'npiprofile.com', '/npi/1902560725', '', '', ''],
#    'engines': ['google'],
#    'positions': [4],
#    'score': 0.25,
#    'category': 'general'},
#   {'url': 'https://www.varnconference.org/wp-content/uploads/English-Final-Conference-Book-061323.pdf',
#    'title': 'conference program',
#    'content': '13-Jun-2023 — Background: The COVID-19 vaccine is a key intervention to reduce morbidity and mortality together with non-pharmaceutical intervention (NPI).149 pages',
#    'thumbnail': None,
#    'engine': 'google',
#    'template': 'default.html',
#    'parsed_url': ['https',
#     'www.varnconference.org',
#     '/wp-content/uploads/English-Final-Conference-Book-061323.pdf',
#     '',
#     '',
#     ''],
#    'engines': ['google'],
#    'positions': [5],
#    'score': 0.2,
#    'category': 'general'},
#   {'url': 'https://npino.com/counselors/tx/austin/?page=141',
#    'title': 'Counselors in Austin, Texas - NPI, Address, Contact',
#    'content': 'NPI Number: 1902501505. Address: 8801 La Cresada Dr Apt 413, , Austin, TX, 78749-4507. Phone: 469-855-4117 Fax: --. Sambavi Venkatesan Counselor - Professional',
#    'thumbnail': None,
#    'engine': 'google',
#    'template': 'default.html',
#    'parsed_url': ['https',
#     'npino.com',
#     '/counselors/tx/austin/',
#     '',
#     'page=141',
#     ''],
#    'engines': ['google'],
#    'positions': [6],
#    'score': 0.16666666666666666,
#    'category': 'general'},
#   {'url': 'https://healthy.kaiserpermanente.org/content/dam/kporg/final/documents/directories/regional-directories/medicaid/provider-directory-east-bay-vi.pdf',
#    'title': 'Danh Bạ Nhà Cung Cấp Khu Vực Phía Đông Vùng Vịnh',
#    'content': '... NPI Number. Số NPI. ObGyn. Sản Khoa/Phụ Khoa. Obstetrics/Gynecology appointments ... Venkatesan, MD Female | License: 112551-CA | NPI Number:1548434335 ...',
#    'thumbnail': None,
#    'engine': 'google',
#    'template': 'default.html',
#    'parsed_url': ['https',
#     'healthy.kaiserpermanente.org',
#     '/content/dam/kporg/final/documents/directories/regional-directories/medicaid/provider-directory-east-bay-vi.pdf',
#     '',
#     '',
#     ''],
#    'engines': ['google'],
#    'positions': [7],
#    'score': 0.14285714285714285,
#    'category': 'general'},
#   {'url': 'https://www.researchgate.net/publication/377183774_Trace_metals_and_pesticides_in_water-sediment_and_associated_pollution_load_indicators_of_Netravathi-Gurupur_estuary_India_Implications_on_coastal_pollution',
#    'title': 'Trace metals and pesticides in water-sediment ...',
#    'content': 'Trace metals and pesticides in water-sediment and associated pollution load indicators of Netravathi-Gurupur estuary, India: Implications on coastal pollution.',
#    'thumbnail': None,
#    'engine': 'google',
#    'template': 'default.html',
#    'parsed_url': ['https',
#     'www.researchgate.net',
#     '/publication/377183774_Trace_metals_and_pesticides_in_water-sediment_and_associated_pollution_load_indicators_of_Netravathi-Gurupur_estuary_India_Implications_on_coastal_pollution',
#     '',
#     '',
#     ''],
#    'engines': ['google'],
#    'positions': [8],
#    'score': 0.125,
#    'category': 'general'},
#   {'url': 'https://www.econstor.eu/bitstream/10419/237290/1/1767274726.pdf',
#    'title': 'The long shadow of an infection: COVID-19 and ...',
#    'content': 'by K Fischer · 2021 · Cited by 17 — These stud- ies have in common that they investigate NPI shocks implemented due to the pandemic ... Venkatesan, P. (2021). NICE guideline on long ...46 pages',
#    'thumbnail': None,
#    'engine': 'google',
#    'template': 'default.html',
#    'parsed_url': ['https',
#     'www.econstor.eu',
#     '/bitstream/10419/237290/1/1767274726.pdf',
#     '',
#     '',
#     ''],
#    'engines': ['google'],
#    'positions': [9],
#    'score': 0.1111111111111111,
#    'category': 'general'}],
#  'answers': [],
#  'corrections': [],
#  'infoboxes': [],
#  'suggestions': [],
#  'unresponsive_engines': []}
